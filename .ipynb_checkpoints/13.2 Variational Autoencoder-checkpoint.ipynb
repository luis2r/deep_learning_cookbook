# %%
import numpy as np
from keras.layers import Input, Dense, Lambda
from keras.layers.merge import concatenate as concat
from keras.models import Model
from keras import backend as K
from keras.datasets import mnist
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping
from keras.optimizers import Adam

from io import BytesIO
import PIL
from IPython.display import clear_output, Image, display, HTML
# Out:
# Using TensorFlow backend.

# %%
def prepare(images, labels):
    images = images.astype('float32') / 255
    n, w, h = images.shape
    return images.reshape((n, w * h)), to_categorical(labels)

train, test = mnist.load_data()
x_train, y_train = prepare(*train)
x_test, y_test = prepare(*test)
img_width, img_height = train[0].shape[1:]

# %%
batch_size = 250
latent_space_depth = 2

def sample_z(args):
    z_mean, z_log_var = args
    eps = K.random_normal(shape=(batch_size, latent_space_depth), mean=0., stddev=1.)
    return z_mean + K.exp(z_log_var / 2) * eps

# %%
def VariationalAutoEncoder(num_pixels):
    pixels = Input(shape=(num_pixels,))
    encoder_hidden = Dense(512, activation='relu')(pixels)

    z_mean = Dense(latent_space_depth, activation='linear')(encoder_hidden)
    z_log_var = Dense(latent_space_depth, activation='linear')(encoder_hidden)
    
    def KL_loss(y_true, y_pred):
        return(0.5 * K.sum(K.exp(z_log_var) + K.square(z_mean) - 1 - z_log_var, axis=1))

    def reconstruction_loss(y_true, y_pred):
        return K.sum(K.binary_crossentropy(y_true, y_pred), axis=-1)    

    def total_loss(y_true, y_pred):
        return KL_loss(y_true, y_pred) + reconstruction_loss(y_true, y_pred)

    z = Lambda(sample_z, output_shape=(latent_space_depth, ))([z_mean, z_log_var])
    
    decoder_hidden = Dense(512, activation='relu')

    reconstruct_pixels = Dense(num_pixels, activation='sigmoid')

    decoder_in = Input(shape=(latent_space_depth,))
    hidden = decoder_hidden(decoder_in)
    decoder_out = reconstruct_pixels(hidden)
    decoder = Model(decoder_in, decoder_out)    
    
    hidden = decoder_hidden(z)
    outputs = reconstruct_pixels(hidden)
    auto_encoder = Model(pixels, outputs)

    auto_encoder.compile(optimizer=Adam(lr=0.001), 
                         loss=total_loss,
                         metrics=[KL_loss, reconstruction_loss])
    
    return auto_encoder, decoder

auto_encoder, decoder = VariationalAutoEncoder(x_train.shape[1])
auto_encoder.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 784)          0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          401920      input_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 2)            1026        dense_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 2)            1026        dense_1[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 2)            0           dense_2[0][0]
#                                                                  dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 512)          1536        lambda_1[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 784)          402192      dense_4[1][0]
# ==================================================================================================
# Total params: 807,700
# Trainable params: 807,700
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((60000, 784), (60000, 10), (10000, 784), (10000, 10))

# %%
auto_encoder.fit(x_train, x_train, verbose=1, 
                 batch_size=batch_size, epochs=100,
                 validation_data=(x_test, x_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
# 60000/60000 [==============================] - 2s 33us/step - loss: 214.9384 - KL_loss: 10.4526 - reconstruction_loss: 204.4858 - val_loss: 181.1154 - val_KL_loss: 5.3095 - val_reconstruction_loss: 175.8060
# Epoch 2/100
# 60000/60000 [==============================] - 1s 19us/step - loss: 176.0094 - KL_loss: 4.8440 - reconstruction_loss: 171.1655 - val_loss: 171.6654 - val_KL_loss: 4.7618 - val_reconstruction_loss: 166.9036
# Epoch 3/100
# 60000/60000 [==============================] - 1s 19us/step - loss: 170.2299 - KL_loss: 4.7736 - reconstruction_loss: 165.4563 - val_loss: 168.4813 - val_KL_loss: 4.8809 - val_reconstruction_loss: 163.6005
# Epoch 4/100
# 60000/60000 [==============================] - 1s 19us/step - loss: 167.4703 - KL_loss: 4.9684 - reconstruction_loss: 162.5019 - val_loss: 166.1747 - val_KL_loss: 5.0961 - val_reconstruction_loss: 161.0786
# Epoch 5/100
# 60000/60000 [==============================] - 1s 19us/step - loss:
100
# 60000/60000 [==============================] - 1s 19us/step - loss: 145.3551 - KL_loss: 6.4239 - reconstruction_loss: 138.9312 - val_loss: 151.7073 - val_KL_loss: 6.3684 - val_reconstruction_loss: 145.3389
# Epoch 94/100
# 60000/60000 [==============================] - 1s 19us/step - loss: 145.2749 - KL_loss: 6.4302 - reconstruction_loss: 138.8446 - val_loss: 151.7632 - val_KL_loss: 6.3787 - val_reconstruction_loss: 145.3846
# Epoch 95/100
# 60000/60000 [==============================] - 1s 19us/step - loss: 145.1871 - KL_loss: 6.4364 - reconstruction_loss: 138.7508 - val_loss: 151.7516 - val_KL_loss: 6.3775 - val_reconstruction_loss: 145.3741
# Epoch 96/100
# 60000/60000 [==============================] - 1s 19us/step - loss: 145.1471 - KL_loss: 6.4312 - reconstruction_loss: 138.7159 - val_loss: 151.7229 - val_KL_loss: 6.3463 - val_reconstruction_loss: 145.3766
# Epoch 97/100
# 60000/60000 [==============================] - 1s 19us/step - loss: 145.0773 - KL_loss: 6.4396 - reconstruction_loss: 138.6376 - val_loss: 151.6372 - val_KL_loss: 6.3552 - val_reconstruction_loss: 145.2820
# Epoch 98/100
# 60000/60000 [==============================] - 1s 19us/step - loss: 145.0110 - KL_loss: 6.4412 - reconstruction_loss: 138.5698 - val_loss: 151.9933 - val_KL_loss: 6.3888 - val_reconstruction_loss: 145.6045
# Epoch 99/100
# 60000/60000 [==============================] - 1s 19us/step - loss: 144.9374 - KL_loss: 6.4524 - reconstruction_loss: 138.4850 - val_loss: 151.4014 - val_KL_loss: 6.2836 - val_reconstruction_loss: 145.1178
# Epoch 100/100
# 60000/60000 [==============================] - 1s 19us/step - loss: 144.8941 - KL_loss: 6.4434 - reconstruction_loss: 138.4507 - val_loss: 151.9668 - val_KL_loss: 6.4125 - val_reconstruction_loss: 145.5542

# %%
random_number = np.asarray([[np.random.normal() 
                            for _ in range(latent_space_depth)]])
def decode_img(a):
    a = np.clip(a * 256, 0, 255).astype('uint8')
    return PIL.Image.fromarray(a)

decode_img(decoder.predict(random_number).reshape(img_width, img_height)).resize((56, 56))
# Out:
# <PIL.Image.Image image mode=L size=56x56 at 0x7F903433C4A8>

# %%
num_cells = 10

overview = PIL.Image.new('RGB', 
                         (num_cells * (img_width + 4) + 8, 
                          num_cells * (img_height + 4) + 8), 
                         (128, 128, 128))

vec = np.zeros((1, latent_space_depth))
for x in range(num_cells):
    vec[:, 0] = (x * 3) / (num_cells - 1) - 1.5
    for y in range(num_cells):
        vec[:, 1] = (y * 3) / (num_cells - 1) - 1.5
        decoded = decoder.predict(vec)
        img = decode_img(decoded.reshape(img_width, img_height))
        overview.paste(img, (x * (img_width + 4) + 6, y * (img_height + 4) + 6))
overview
# Out:
# <PIL.Image.Image image mode=RGB size=328x328 at 0x7F9034353358>

# %%
def ConditionalVariationalAutoEncoder(num_pixels, num_labels):
    pixels = Input(shape=(num_pixels,))
    label = Input(shape=(num_labels,), name='label')

    inputs = concat([pixels, label], name='inputs')
    
    encoder_hidden = Dense(512, activation='relu', name='encoder_hidden')(inputs)

    z_mean = Dense(latent_space_depth, activation='linear')(encoder_hidden)
    z_log_var = Dense(latent_space_depth, activation='linear')(encoder_hidden)
    
    def KL_loss(y_true, y_pred):
        return(0.5 * K.sum(K.exp(z_log_var) + K.square(z_mean) - 1 - z_log_var, axis=1))

    def reconstruction_loss(y_true, y_pred):
        return K.sum(K.binary_crossentropy(y_true, y_pred), axis=-1)    

    def total_loss(y_true, y_pred):
        return KL_loss(y_true, y_pred) + reconstruction_loss(y_true, y_pred)

    z = Lambda(sample_z, output_shape=(latent_space_depth, ))([z_mean, z_log_var])
    zc = concat([z, label])
    
    decoder_hidden = Dense(512, activation='relu')

    reconstruct_pixels = Dense(num_pixels, activation='sigmoid')

    decoder_in = Input(shape=(latent_space_depth + num_labels,))
    hidden = decoder_hidden(decoder_in)
    decoder_out = reconstruct_pixels(hidden)
    decoder = Model(decoder_in, decoder_out)    
    
    hidden = decoder_hidden(zc)
    outputs = reconstruct_pixels(hidden)
    auto_encoder = Model([pixels, label], outputs)

    auto_encoder.compile(optimizer=Adam(lr=0.001), 
                         loss=total_loss,
                         metrics=[KL_loss, reconstruction_loss])
    
    return auto_encoder, decoder

cond_auto_encoder, cond_decoder = ConditionalVariationalAutoEncoder(x_train.shape[1], y_train.shape[1])
cond_auto_encoder.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 784)          0
# __________________________________________________________________________________________________
# label (InputLayer)              (None, 10)           0
# __________________________________________________________________________________________________
# inputs (Concatenate)            (None, 794)          0           input_3[0][0]
#                                                                  label[0][0]
# __________________________________________________________________________________________________
# encoder_hidden (Dense)          (None, 512)          407040      inputs[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 2)            1026        encoder_hidden[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 2)            1026        encoder_hidden[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 2)            0           dense_6[0][0]
#                                                                  dense_7[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 12)           0           lambda_2[0][0]
#                                                                  label[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 512)          6656        concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 784)          402192      dense_8[1][0]
# ==================================================================================================
# Total params: 817,940
# Trainable params: 817,940
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
cond_auto_encoder.fit([x_train, y_train], x_train, verbose=1, 
                      batch_size=batch_size, epochs=50,
                      validation_data = ([x_test, y_test], x_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 2s 26us/step - loss: 199.9344 - KL_loss: 9.6688 - reconstruction_loss: 190.2657 - val_loss: 155.8687 - val_KL_loss: 4.2932 - val_reconstruction_loss: 151.5755
# Epoch 2/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 149.2065 - KL_loss: 4.2665 - reconstruction_loss: 144.9400 - val_loss: 144.8677 - val_KL_loss: 4.1765 - val_reconstruction_loss: 140.6912
# Epoch 3/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 143.0832 - KL_loss: 4.2894 - reconstruction_loss: 138.7938 - val_loss: 141.2234 - val_KL_loss: 4.1728 - val_reconstruction_loss: 137.0506
# Epoch 4/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 140.4147 - KL_loss: 4.3109 - reconstruction_loss: 136.1037 - val_loss: 139.3815 - val_KL_loss: 4.1822 - val_reconstruction_loss: 135.1994
# Epoch 5/50
# 60000/60000 [==============================] - 1s 20us/step - loss: 138.7676 - KL_loss: 4.3299 - reconstruction_loss: 134.4377 - val_loss: 138.0795 - val_KL_loss: 4.2489 - val_reconstruction_loss: 133.8307
# Epoch 6/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 137.5580 - KL_loss: 4.3439 - reconstruction_loss: 133.2141 - val_loss: 137.0545 - val_KL_loss: 4.3965 - val_reconstruction_loss: 132.6579
# Epoch 7/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 136.6158 - KL_loss: 4.3539 - reconstruction_loss: 132.2619 - val_loss: 136.1874 - val_KL_loss: 4.3197 - val_reconstruction_loss: 131.8678
# Epoch 8/50
# 60000/60000 [==============================] - 1s 20us/step - loss: 135.8875 - KL_loss: 4.3938 - reconstruction_loss: 131.4937 - val_loss: 135.4888 - val_KL_loss: 4.3723 - val_reconstruction_loss: 131.1165
# Epoch 9/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 135.2413 - KL_loss: 4.4191 - reconstruction_loss: 130.8222 - val_loss: 135.0443 - val_KL_loss: 4.3996 - val_reconstruction_loss: 130.6447
# Epoch 10/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 134.7183 - KL_loss: 4.4447 - reconstruction_loss: 130.2736 - val_loss: 134.6047 - val_KL_loss: 4.3440 - val_reconstruction_loss: 130.2607
# Epoch 11/50
# 60000/60000 [==============================] - 1s 19us/step - loss:
50
# 60000/60000 [==============================] - 1s 19us/step - loss: 129.4964 - KL_loss: 4.7155 - reconstruction_loss: 124.7809 - val_loss: 130.8426 - val_KL_loss: 4.6466 - val_reconstruction_loss: 126.1961
# Epoch 46/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 129.4654 - KL_loss: 4.7269 - reconstruction_loss: 124.7385 - val_loss: 130.8720 - val_KL_loss: 4.6137 - val_reconstruction_loss: 126.2582
# Epoch 47/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 129.4389 - KL_loss: 4.7405 - reconstruction_loss: 124.6985 - val_loss: 130.7224 - val_KL_loss: 4.6823 - val_reconstruction_loss: 126.0400
# Epoch 48/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 129.3456 - KL_loss: 4.7448 - reconstruction_loss: 124.6008 - val_loss: 130.6832 - val_KL_loss: 4.6408 - val_reconstruction_loss: 126.0424
# Epoch 49/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 129.3227 - KL_loss: 4.7458 - reconstruction_loss: 124.5768 - val_loss: 130.6689 - val_KL_loss: 4.5910 - val_reconstruction_loss: 126.0778
# Epoch 50/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 129.2628 - KL_loss: 4.7417 - reconstruction_loss: 124.5211 - val_loss: 130.6730 - val_KL_loss: 4.5808 - val_reconstruction_loss: 126.0922

# %%
number_4 = np.zeros((1, latent_space_depth + y_train.shape[1]))
number_4[:, 4 + latent_space_depth] = 1
decode_img(cond_decoder.predict(number_4).reshape(
               img_width, img_height)).resize((56, 56))
# Out:
# <PIL.Image.Image image mode=L size=56x56 at 0x7F90006F0358>

# %%
number_8_3 = np.zeros((1, latent_space_depth + y_train.shape[1]))
number_8_3[:, 8 + latent_space_depth] = 0.5
number_8_3[:, 3 + latent_space_depth] = 0.5
decode_img(cond_decoder.predict(number_8_3).reshape(
               img_width, img_height)).resize((56, 56))
# Out:
# <PIL.Image.Image image mode=L size=56x56 at 0x7F90006F0588>

# %%
digits = [3, 0, 8, 9]
num_cells = 10

overview = PIL.Image.new('RGB', 
                         (num_cells * (img_width + 4) + 8, 
                          num_cells * (img_height + 4) + 8), 
                         (128, 128, 128))

vec = np.zeros((1, latent_space_depth + y_train.shape[1]))
for x in range(num_cells):
    x1 = [x / (num_cells - 1), 1 - x / (num_cells - 1)]
    for y in range(num_cells):
        y1 = [y / (num_cells - 1), 1 - y / (num_cells - 1)]
        for idx, dig in enumerate(digits):
            vec[:, dig + latent_space_depth] = x1[idx % 2] * y1[idx // 2]
        decoded = cond_decoder.predict(vec)
        img = decode_img(decoded.reshape(img_width, img_height))
        overview.paste(img, (x * (img_width + 4) + 6, y * (img_height + 4) + 6))
overview
# Out:
# <PIL.Image.Image image mode=RGB size=328x328 at 0x7F90006FBF60>

# %%
num_cells = 10

overview = PIL.Image.new('RGB', 
                         (num_cells * (img_width + 4) + 8, 
                          num_cells * (img_height + 4) + 8), 
                         (128, 128, 128))

img_it = 0
vec = np.zeros((1, latent_space_depth + y_train.shape[1]))
for x in range(num_cells):
    vec = np.zeros((1, latent_space_depth + y_train.shape[1]))
    vec[:, x + latent_space_depth] = 1
    for y in range(num_cells):
        vec[:, 1] = 3 * y / (num_cells - 1) - 1.5
        decoded = cond_decoder.predict(vec)
        img = decode_img(decoded.reshape(img_width, img_height))
        overview.paste(img, (x * (img_width + 4) + 6, y * (img_height + 4) + 6))
overview
# Out:
# <PIL.Image.Image image mode=RGB size=328x328 at 0x7F90006FBC50>
